# %%
 #-*- coding: utf-8 -*-
import sys

#기본세팅 - 데이터 획득 준비 작업
import pandas as pd
import numpy as np
import googlemaps

import matplotlib.pyplot as plt
# %matplotlib inline

#matplotlib 한글폰트 로딩
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
     path = "c:/Windows/Fonts/malgun.ttf"
     font_name = font_manager.FontProperties(fname=path).get_name()
     rc('font', family=font_name)
else:
     print('Unknown system... sorry~~~~')
      
plt.rcParams['axes.unicode_minus'] = False

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests

url = 'http://e-childschoolinfo.moe.go.kr/kinderMt/kinderFind.do?sidoList=11'
r = requests.get(url)

soup = BeautifulSoup(r.content, "html.parser")

soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.5,minimum-scale=1.0,user-scalable=yes,target-densitydpi=medium-dpi" name="viewport">
# <meta content="모바일 알리미" name="description"/>
# <meta content="KERIS, 유치원 공시, 유치원 모바일 알리미" name="keywords"/>
# <meta content="(주)유엔파인" name="author"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/><!-- 호환성 보기 막기 -->
# <title>유치원 알리미</title>
# <link href="/css/jquery-ui.css;jsessionid=hi9DpHEJn0yXijlFD3JsmMbjLvK1cnat9o1Wy2qbhD8qhmmQ01mYzEPhmJPUYLog.ies-kirwas1_servlet_engine1" rel="stylesheet" type="text/css"/>
# <link href="/css/reset.css;jsessionid=hi9DpHEJn0yXijlFD3JsmMbjLvK1cnat9o1Wy2qbhD8qhmmQ01mYzEPhmJPUYLog.ies-kirwas1_servlet_engine1" rel="stylesheet" type="text/css"/><!-- css초기화 -->
# ...

# %%
total_kinder_number = soup.find('div', attrs={'class':'contents'}).find('h1').text	#화면내에 떠있는 Total number를 가져온다. 
total_kinder_number = int(total_kinder_number.split(' ')[2][:-2].replace(',',''))	

total_kinder_number, r.cookies
# Out:
# (962,
#  <RequestsCookieJar[Cookie(version=0, name='JSESSIONID', value='hi9DpHEJn0yXijlFD3JsmMbjLvK1cnat9o1Wy2qbhD8qhmmQ01mYzEPhmJPUYLog.ies-kirwas1_servlet_engine1', port=None, port_specified=False, domain='e-childschoolinfo.moe.go.kr', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False)]>)

# %%
#def get_list(total_kinder_number):
kinder_id_list = []
list_url = 'http://e-childschoolinfo.moe.go.kr/kinderMt/kinderFind.do'
list_form = {
    'sidoList':11,
    'sggList':99,
    'establishmentType':99,
    'pageIndex':0
    } 

list_r = requests.get(list_url, data=list_form)		#유치원 별 url을 가져온다. 
while(True) :
    list_form['pageIndex'] += 1
    list_r = requests.get(list_url, data=list_form)
    soup = bs4.BeautifulSoup(list_r.content, 'html.parser')
    try :
        kinder_list = soup.find('ul', attrs={'class':'chkList'}).find_all('input')	#chk 항목을 가져온다.
    except :
        break
    for kinder in kinder_list:
        kinder_id_list.append(kinder.attrs['value'])	#모든 value를 가져온다.
    
kinder_id_list
# Out:
# ['1ecec08d-04f4-b044-e053-0a32095ab044',
#  '1ecec08c-f734-b044-e053-0a32095ab044',
#  '34140010-58e8-44b4-9e91-49d5eb6669e1',
#  '1ecec08c-ed13-b044-e053-0a32095ab044',
#  '1ecec08d-0561-b044-e053-0a32095ab044',
#  '1ecec08c-f973-b044-e053-0a32095ab044',
#  '1ecec08c-ee46-b044-e053-0a32095ab044',
#  '1ecec08c-f446-b044-e053-0a32095ab044',
#  '1ecec08c-fdba-b044-e053-0a32095ab044',
#  '1ecec08c-ee4e-b044-e053-0a32095ab044',
#  '1ecec08c-fbfd-b044-e053-0a32095ab044',
#  '1ecec08d-09ab-b044-e053-0a32095ab044',
#  '1ecec08c-ed14-b044-e053-0a32095ab044',
#  '1ecec08c-f507-b044-e053-0a32095ab044',
#  '1ecec08c-f64b-b044-e053-0a32095ab044',
#  '1ecec08d-0e6c-b044-e053-0a32095ab044',
#  '1ecec08d-0341-b044-e053-0a32095ab044',
#  '1ecec08d-0250-b044-e053-0a32095ab044',
#  '1ecec08d-0754-b044-e053-0a32095ab044',
#  '1ecec08d-0d38-b044-e053-0a32095ab044',
#  '1ecec08c-f7f5-b044-e053-0a32095ab044',
#  '1ecec08d-042a-b044-e053-0a32095ab044',
#  '1ecec08c-f12c-b044-e053-0a32095ab044',
# ...

# %%
kinder_name = []
boss = []
director = []
established_type = []
established_date = []
start_date = []
admin_department = []
tel = []
homepage = []
operating_hour = []
address = []
service = []
age_3_class = []
age_3_student = []
age_4_class = []
age_4_student = []
age_5_class = []
age_5_student = []
age_3_4_class = []
age_3_4_student = []
age_4_5_class = []
age_4_5_student = []
age_3_5_class = []
age_3_5_student = []
handicap_class = []
handicap_student = []

stud_capa = []
stud_regi = []
staff_director = []
staff_sub_director = []
staff_chief_teacher = []
staff_manager_teacher = []
staff_teacher = []
staff_special_teacher = []
staff_health_teacher = []
staff_nutrient_teacher = []
staff_term_teacher = []
staff_office_worker = []
staff_chief_grade = []
staff_1st_grade = []
staff_2nd_grade = []
staff_basic_grade = []
under_1 = []
over_1_under_2 = []
over_2_under_4 = []
over_4_under_6 = []
over_6 = []
certification_date = []


from tqdm import tqdm_notebook

for kinder_id in tqdm_notebook(kinder_id_list):

    detail_url = 'http://e-childschoolinfo.moe.go.kr/kinderMt/kinderSummary.do'
    list_form = {
        'sidoList':99,
        'sggList':99,
        'establishmentType':99,
        'ittId':kinder_id,
        'pageIndex':1
        }
    detail_r = requests.post(detail_url, data=list_form)

    table = bs4.BeautifulSoup(detail_r.content, 'html.parser').find_all('tr')
    
    service_list = []
    if 'checked' in table[11].select('#preschool-service-1')[0].attrs:
        service_list.append('방과후과정')
    if 'checked' in table[11].select('#preschool-service-2')[0].attrs:
        service_list.append('특수학급')
    if 'checked' in table[11].select('#preschool-service-3')[0].attrs:
        service_list.append('아침돌봄')
    if 'checked' in table[11].select('#preschool-service-4')[0].attrs:
        service_list.append('저녁돌봄')
    if 'checked' in table[11].select('#preschool-service-5')[0].attrs:
        service_list.append('온종일돌봄')
    if 'checked' in table[11].select('#preschool-service-6')[0].attrs:
        service_list.append('해당없음')
        
        
    kinder_name.append(table[0].find('td').text.strip())
    boss.append(table[1].find('td').text.strip())
    director.append(table[2].find('td').text.strip())
    established_type.append(table[3].find('td').text.strip())
    established_date.append(table[4].find('td').text.strip())
    start_date.append(table[5].find('td').text.strip())
    admin_department.append(table[6].find('td').text.strip())
    tel.append(table[7].find('td').text.strip())
    homepage.append(table[8].find('td').text.strip())
    operating_hour.append(table[9].find('td').text.strip())
    address.append(table[10].find('td').text.strip())
    service.append(service_list)
    age_3_class.append(table[14].find_all('td')[0].text.strip().replace(',',''))
    age_4_class.append(table[14].find_all('td')[1].text.strip().replace(',',''))
    age_5_class.append(table[14].find_all('td')[2].text.strip().replace(',',''))
    age_3_4_class.append(table[14].find_all('td')[3].text.strip().replace(',',''))
    age_4_5_class.append(table[14].find_all('td')[4].text.strip().replace(',',''))
    age_3_5_class.append(table[14].find_all('td')[5].text.strip().replace(',',''))
    handicap_class.append(table[14].find_all('td')[6].text.strip().replace(',',''))

    age_3_student.append(table[15].find_all('td')[0].text.strip().replace(',',''))
    age_4_student.append(table[15].find_all('td')[1].text.strip().replace(',',''))
    age_5_student.append(table[15].find_all('td')[2].text.strip().replace(',',''))
    age_3_4_student.append(table[15].find_all('td')[3].text.strip().replace(',',''))
    age_4_5_student.append(table[15].find_all('td')[4].text.strip().replace(',',''))
    age_3_5_student.append(table[15].find_all('td')[5].text.strip().replace(',',''))
    handicap_student.append(table[15].find_all('td')[6].text.strip().replace(',',''))

    certification_date.append(table[18].find_all('td')[1].text.strip().replace(',',''))

    staff_url = 'http://e-childschoolinfo.moe.go.kr/kinderMt/kinderChildAndStaff.do'
    list_form = {
        'ittId':kinder_id,
        'pageIndex':1
        }
    staff_r = requests.post(staff_url, data=list_form)

    staff = BeautifulSoup(staff_r.content, 'html.parser')
    stud_capa.append(staff.select('.content')[0].select('td')[0].text.strip().replace(',',''))
    stud_regi.append(staff.select('.content')[0].select('td')[1].text.strip().replace(',',''))

    staff_director.append(staff.select('.content')[1].select('td')[1].text.strip().replace(',',''))
    staff_sub_director.append(staff.select('.content')[1].select('td')[2].text.strip().replace(',',''))
    staff_chief_teacher.append(staff.select('.content')[1].select('td')[3].text.strip().replace(',',''))
    staff_manager_teacher.append(staff.select('.content')[1].select('td')[4].text.strip().replace(',',''))
    staff_teacher.append(staff.select('.content')[1].select('td')[5].text.strip().replace(',',''))
    staff_special_teacher.append(staff.select('.content')[1].select('td')[6].text.strip().replace(',',''))
    staff_health_teacher.append(staff.select('.content')[1].select('td')[7].text.strip().replace(',',''))
    staff_nutrient_teacher.append(staff.select('.content')[1].select('td')[8].text.strip().replace(',',''))
    staff_term_teacher.append(staff.select('.content')[1].select('td')[9].text.strip().replace(',',''))
    staff_office_worker.append(staff.select('.content')[1].select('td')[10].text.strip().replace(',',''))

    staff_chief_grade.append(staff.select('.content')[1].select('td')[11].text.strip().replace(',',''))
    staff_1st_grade.append(staff.select('.content')[1].select('td')[12].text.strip().replace(',',''))
    staff_2nd_grade.append(staff.select('.content')[1].select('td')[13].text.strip().replace(',',''))
    staff_basic_grade.append(staff.select('.content')[1].select('td')[13].text.strip().replace(',',''))

    under_1.append(staff.select('.content')[2].select('td')[0].text.strip().replace(',',''))
    over_1_under_2.append(staff.select('.content')[2].select('td')[1].text.strip().replace(',',''))
    over_2_under_4.append(staff.select('.content')[2].select('td')[2].text.strip().replace(',',''))
    over_4_under_6.append(staff.select('.content')[2].select('td')[3].text.strip().replace(',',''))
    over_6.append(staff.select('.content')[2].select('td')[4].text.strip().replace(',',''))

# %%
kinder_info = pd.DataFrame({
  '유치원명': kinder_name,  
  '대표자':boss,  
  '원장':director,  
  '설립일자':established_date,  
  '설립유형':established_type, 
  '개원일자':start_date,  
  '담당행정기관':admin_department,  
  '전화번호':tel,  
  '홈페이지':homepage,  
  '운영시간':operating_hour,  
  '주소':address,  
  '제공서비스':service,  
  '3세반학급':age_3_class,  
  '4세반학급':age_4_class,  
  '5세반학급':age_5_class,  
  '3~4세반학급':age_3_4_class,  
  '4~5세반학급':age_4_5_class,  
  '3~5세반학급':age_3_5_class,  
  '특수/장애반학급':handicap_class,  
  '3세반학생수':age_3_student,  
  '4세반학생수':age_4_student,  
  '5세반학생수':age_5_student,  
  '3~4세반학생수':age_3_4_student,  
  '4~5세반학생수':age_4_5_student,  
  '3~5세반학생수':age_3_5_student,  
  '특수/장애반학생수':handicap_student,  
  '원장수':staff_director,  
  '원감수':staff_sub_director,  
  '수석교사':staff_chief_teacher,  
  '보직교사':staff_manager_teacher, 
  '교사':staff_teacher,  
  '특수교사':staff_special_teacher,  
  '보건교사':staff_health_teacher,  
  '영양교사':staff_nutrient_teacher,  
  '기간제교원': staff_term_teacher, 
  '사무직원': staff_office_worker,  
  '수석교사':staff_chief_grade,  
  '1급정교사':staff_1st_grade,  
  '2급정교사':staff_2nd_grade,  
  '준교사':staff_basic_grade,  
  '1년미만':under_1,  
  '1년이상2년미만': over_1_under_2,  
  '2년이상4년미만': over_2_under_4,  
  '4년이상6년미만':over_4_under_6, 
  '6년이상':over_6,  
  '평가(인증)년월':certification_date 
})

kinder_info.head()
# Out:
#   1급정교사 1년미만 1년이상2년미만 2급정교사 2년이상4년미만 3~4세반학급 3~4세반학생수 3~5세반학급 3~5세반학생수 3세반학급  \
# 0     2    3        5     6        0       0        0       0        0     0
# 1     0    2        0     3        1       0        0       0        0     1
# 2     2   16        0    14        0       0        0       0        0     5
# 3     2    3        2     6        1       0        0       0        0     1
# 4     1    1        3     4        1       0        0       0        0     1
#
#             ...                유치원명          전화번호    제공서비스  \
# 0           ...               가람유치원   02-427-3151  [방과후과정]
# 1           ...               가명유치원   02-362-7593   [해당없음]
# 2           ...             강남유정유치원  02-2226-9500  [방과후과정]
# 3           ...               강남유치원   02-546-1673  [방과후과정]
# 4           ...               강남유치원   02-813-7122  [방과후과정]
#
#                      주소 준교사 특수/장애반학급 특수/장애반학생수 특수교사   평가(인증)년월  \
# 0   서울특별시 강동구 상암로63길 39   6        0         0    0  2014년 10월
# ...

# %%
kinder_info = kinder_info.loc[:,  ['유치원명',  '대표자',  '원장',  '설립일자',  '설립유형',  '개원일자',  '담당행정기관', '전화번호', '홈페이지', '운영시간', '주소', '제공서비스', '3세반학급', '4세반학급', '5세반학급', '3~4세반학급', '4~5세반학급', '3~5세반학급', '특수/장애반학급', '3세반학생수', '4세반학생수', '5세반학생수', '3~4세반학생수', '4~5세반학생수', '3~5세반학생수', '특수/장애반학생수', '원장수', '원감수', '수석교사', '보직교사', '교사', '특수교사', '보건교사', '영양교사', '기간제교원', '사무직원', '수석교사', '1급정교사', '2급정교사', '준교사', '1년미만', '1년이상2년미만', '2년이상4년미만', '4년이상6년미만', '6년이상', '평가(인증)년월']]
kinder_info.head()
# Out:
#       유치원명       대표자   원장        설립일자    설립유형        개원일자  \
# 0    가람유치원       박민정  이형미  1986-11-27  사립(사인)  1987-03-10
# 1    가명유치원       염수정  노현경  1956-04-15  사립(법인)  1956-04-15
# 2  강남유정유치원  김지은, 박민정  박민정  2018-01-31  사립(사인)  2018-03-01
# 3    강남유치원       피영민  박춘옥  1985-02-01  사립(사인)  1985-02-01
# 4    강남유치원       정지건  이성미  1971-03-30  사립(사인)  1971-03-30
#
#                  담당행정기관          전화번호                     홈페이지  \
# 0  서울특별시교육청 / 강동송파교육지원청   02-427-3151          등록된 홈페이지가 없습니다.
# 1    서울특별시교육청 / 중부교육지원청   02-362-7593          등록된 홈페이지가 없습니다.
# 2  서울특별시교육청 / 강남서초교육지원청  02-2226-9500  http://www.gnyujung.com
# 3  서울특별시교육청 / 강남서초교육지원청   02-546-1673          등록된 홈페이지가 없습니다.
# 4  서울특별시교육청 / 동작관악교육지원청   02-813-7122          등록된 홈페이지가 없습니다.
#
#                 운영시간    ...     수석교사 1급정교사 2급정교사 준교사 1년미만 1년이상2년미만 2년이상4년미만  \
# 0  09 : 00 ~ 19 : 00    ...        0     2     6   6    3        5        0
# 1  09 : 00 ~ 14 : 00    ...        0     0     3   3    2        0        1
# ...

# %%
kinder_info['주소']
# Out:
# 0        서울특별시 강동구 상암로63길 39
# 1         서울특별시 중구 청파로 447-1
# 2        서울특별시 강남구 광평로34길 17
# 3       서울특별시 강남구 선릉로129길 31
# 4       서울특별시 동작구 상도로41가길 13
# 5        서울특별시 강동구 상일로10길 41
# 6       서울특별시 용산구 이촌로84길 9-7
# 7         서울특별시 강서구 까치산로 116
# 8       서울특별시 강동구 아리수로98길 62
# 9         서울특별시 성북구 보국문로 143
# 10       서울특별시 구로구 개봉로18길 11
# 11         서울특별시 관악구 조원로 114
# 12          서울특별시 강남구 삼성로 14
# 13         서울특별시 성동구 금호로 100
# 14      서울특별시 서대문구 세검정로1길 95
# 15        서울특별시 양천구 목동로3길 57
# 16         서울특별시 광진구 영화사로 89
# 17       서울특별시 강북구 노해로21길 12
# 18        서울특별시 광진구 동일로72길 9
# 19        서울특별시 동대문구 경희대로 26
# 20     서울특별시 양천구 남부순환로86길 22
# 21      서울특별시 용산구 효창원로15길 15
# 22        서울특별시 강동구 구천면로 645
# 23       서울특별시 강동구 양재대로 1706
# 24      서울특별시 노원구 동일로208길 34
# 25      서울특별시 노원구 동일로186길 27
# 26     서울특별시 강서구 개화동로23길 100
# 27      서울특별시 광진구 아차산로70길 40
# 28     서울특별시 양천구 남부순환로30길 17
# 29        서울특별시 성북구 장월로42길 9
#                ...
# 932      서울특별시 동작구 양녕로23길 25
# ...

# %%
gmaps_key = "AIzaSyCVc3Mc-v8efQxIykNPK8nqFXK9DaE7KA4"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
from tqdm import tqdm_notebook

lat = []
lng = []

for n in tqdm_notebook(kinder_info.index):
    try:
        tmp_add = str(kinder_info['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)
        
        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
        
        
kinder_info['lat'] = lat
kinder_info['lng'] = lng
kinder_info.head()
# Out:
# ...
#       유치원명       대표자   원장        설립일자    설립유형        개원일자  \
# 0    가람유치원       박민정  이형미  1986-11-27  사립(사인)  1987-03-10
# 1    가명유치원       염수정  노현경  1956-04-15  사립(법인)  1956-04-15
# 2  강남유정유치원  김지은, 박민정  박민정  2018-01-31  사립(사인)  2018-03-01
# 3    강남유치원       피영민  박춘옥  1985-02-01  사립(사인)  1985-02-01
# 4    강남유치원       정지건  이성미  1971-03-30  사립(사인)  1971-03-30
#
#                  담당행정기관          전화번호                     홈페이지  \
# 0  서울특별시교육청 / 강동송파교육지원청   02-427-3151          등록된 홈페이지가 없습니다.
# 1    서울특별시교육청 / 중부교육지원청   02-362-7593          등록된 홈페이지가 없습니다.
# 2  서울특별시교육청 / 강남서초교육지원청  02-2226-9500  http://www.gnyujung.com
# 3  서울특별시교육청 / 강남서초교육지원청   02-546-1673          등록된 홈페이지가 없습니다.
# 4  서울특별시교육청 / 동작관악교육지원청   02-813-7122          등록된 홈페이지가 없습니다.
#
#                 운영시간     ...     2급정교사 준교사 1년미만 1년이상2년미만 2년이상4년미만 4년이상6년미만  \
# 0  09 : 00 ~ 19 : 00     ...         6   6    3        5        0        0
# 1  09 : 00 ~ 14 : 00     ...         3   3    2        0        1        0
# ...

# %%
kinder_info.to_csv('../data/kinder_info.csv', sep=',', encoding='UTF-8')

# %%
street_address = kinder_info['주소']

# %%
street_address.head()
# Out:
# 0     서울특별시 강동구 상암로63길 39
# 1      서울특별시 중구 청파로 447-1
# 2     서울특별시 강남구 광평로34길 17
# 3    서울특별시 강남구 선릉로129길 31
# 4    서울특별시 동작구 상도로41가길 13
# Name: 주소, dtype: object

# %%
gu_name = []

for name in street_address:
    tmp = name.split()
    
    tmp_gu = [gu for gu in tmp if gu[-1] == '구'][0]
    
    gu_name.append(tmp_gu)
    
kinder_info['구별'] = gu_name
kinder_info.head()
# Out:
#       유치원명       대표자   원장        설립일자    설립유형        개원일자  \
# 0    가람유치원       박민정  이형미  1986-11-27  사립(사인)  1987-03-10
# 1    가명유치원       염수정  노현경  1956-04-15  사립(법인)  1956-04-15
# 2  강남유정유치원  김지은, 박민정  박민정  2018-01-31  사립(사인)  2018-03-01
# 3    강남유치원       피영민  박춘옥  1985-02-01  사립(사인)  1985-02-01
# 4    강남유치원       정지건  이성미  1971-03-30  사립(사인)  1971-03-30
#
#                  담당행정기관          전화번호                     홈페이지  \
# 0  서울특별시교육청 / 강동송파교육지원청   02-427-3151          등록된 홈페이지가 없습니다.
# 1    서울특별시교육청 / 중부교육지원청   02-362-7593          등록된 홈페이지가 없습니다.
# 2  서울특별시교육청 / 강남서초교육지원청  02-2226-9500  http://www.gnyujung.com
# 3  서울특별시교육청 / 강남서초교육지원청   02-546-1673          등록된 홈페이지가 없습니다.
# 4  서울특별시교육청 / 동작관악교육지원청   02-813-7122          등록된 홈페이지가 없습니다.
#
#                 운영시간 ...  준교사 1년미만 1년이상2년미만 2년이상4년미만 4년이상6년미만 6년이상   평가(인증)년월  \
# 0  09 : 00 ~ 19 : 00 ...    6    3        5        0        0    0  2014년 10월
# ...

# %%
준교사
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-6e8198f8aa3a> in <module>()
# ----> 1 준교사
#
# NameError: name '준교사' is not defined

# %%
kinder_info['총 교사수'] = kinder_info['교사'] + kinder_info['준교사'] + kinder_info['기간제교원']

# %%
type(kinder_info['총 교사수'])
# Out:
# pandas.core.series.Series

# %%
kinder_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 962 entries, 0 to 961
# Data columns (total 50 columns):
# 유치원명         962 non-null object
# 대표자          962 non-null object
# 원장           962 non-null object
# 설립일자         962 non-null object
# 설립유형         962 non-null object
# 개원일자         962 non-null object
# 담당행정기관       962 non-null object
# 전화번호         962 non-null object
# 홈페이지         962 non-null object
# 운영시간         962 non-null object
# 주소           962 non-null object
# 제공서비스        962 non-null object
# 3세반학급        962 non-null object
# 4세반학급        962 non-null object
# 5세반학급        962 non-null object
# 3~4세반학급      962 non-null object
# 4~5세반학급      962 non-null object
# 3~5세반학급      962 non-null object
# 특수/장애반학급     962 non-null object
# 3세반학생수       962 non-null object
# 4세반학생수       962 non-null object
# 5세반학생수       962 non-null object
# 3~4세반학생수     962 non-null object
# 4~5세반학생수     962 non-null object
# 3~5세반학생수     962 non-null object
# ...

# %%
kinder_info['교사'] = [float(value) for value in kinder_info['교사']]
kinder_info['준교사'] = [float(value) for value in kinder_info['준교사']]
kinder_info['기간제교원'] = [float(value) for value in kinder_info['기간제교원']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-9e236e009f8b> in <module>()
# ----> 1 kinder_info['교사'] = [float(value) for value in kinder_info['교사']]
#       2 kinder_info['준교사'] = [float(value) for value in kinder_info['준교사']]
#       3 kinder_info['기간제교원'] = [float(value) for value in kinder_info['기간제교원']]
#
# <ipython-input-128-9e236e009f8b> in <listcomp>(.0)
# ----> 1 kinder_info['교사'] = [float(value) for value in kinder_info['교사']]
#       2 kinder_info['준교사'] = [float(value) for value in kinder_info['준교사']]
#       3 kinder_info['기간제교원'] = [float(value) for value in kinder_info['기간제교원']]
#
# ValueError: could not convert string to float: '-'

# %%
kinder_info[kinder_info['교사'] == '-']
# Out:
#                                                   유치원명 대표자 원장        설립일자  \
# 42                                               금란유치원   -  -  1983-12-06
# 97   독산유치원\r\n                  \r\n               ...   -  -  1977-03-08
# 113                                             동서울유치원   -  -  1986-03-01
# 155  마포유치원\r\n                  \r\n               ...   -  -  1984-03-03
# 193                                              반석유치원   -  -  1983-12-14
# 202  배화유치원\r\n                  \r\n               ...   -  -  1988-03-01
# 204                                              백설유치원   -  -  1978-02-14
# 213  별밭유치원\r\n                  \r\n               ...   -  -  1984-09-07
# 244                                              삼원유치원   -  -  1983-08-26
# 251                                              상아유치원   -  -  1987-06-11
# 255  새나유치원\r\n                  \r\n               ...   -  -  1998-10-11
# 259  새별밭유치원\r\n                  \r\n              ...   -  -  1996-03-08
# ...

# %%
kinder_info2 = kinder_info[kinder_info['교사'] != '-']

# %%
kinder_info2['교사'] = [float(value) for value in kinder_info2['교사']]
kinder_info2['준교사'] = [float(value) for value in kinder_info2['준교사']]
kinder_info2['기간제교원'] = [float(value) for value in kinder_info2['기간제교원']]
# Out:
# /Users/wonbang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/wonbang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/wonbang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %%
kinder_info2['총교사수'] = kinder_info2['교사'] + kinder_info2['준교사'] + kinder_info2['기간제교원']
# Out:
# /Users/wonbang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
kinder_info2['총교사수']
# Out:
# 0      14.0
# 1       6.0
# 2      31.0
# 3      14.0
# 4      10.0
# 5      41.0
# 6       9.0
# 7      20.0
# 8      39.0
# 9      17.0
# 10      9.0
# 11     31.0
# 12      7.0
# 13     24.0
# 14     22.0
# 15     21.0
# 16     11.0
# 17     10.0
# 18      8.0
# 19      9.0
# 20     17.0
# 21     28.0
# 22     10.0
# 23     18.0
# 24     29.0
# 25      8.0
# 26     11.0
# 27     21.0
# 28     15.0
# 29      5.0
#        ...
# 932    27.0
# 933    19.0
# 934     8.0
# 935    22.0
# 936    17.0
# 937    10.0
# 938    16.0
# 939     8.0
# 940     7.0
# 941    19.0
# 942    18.0
# 943    13.0
# 944    15.0
# 945     3.0
# 946     6.0
# 947     2.0
# 948    25.0
# 949    20.0
# 950    10.0
# 951     7.0
# 952    11.0
# 953    16.0
# 954     9.0
# 955     4.0
# 956    11.0
# 957     3.0
# 958    22.0
# 959    15.0
# 960    21.0
# 961    16.0
# Name: 총교사수, Length: 929, dtype: float64

# %%
kinder_info2.head()
# Out:
#       유치원명       대표자   원장        설립일자    설립유형        개원일자  \
# 0    가람유치원       박민정  이형미  1986-11-27  사립(사인)  1987-03-10
# 1    가명유치원       염수정  노현경  1956-04-15  사립(법인)  1956-04-15
# 2  강남유정유치원  김지은, 박민정  박민정  2018-01-31  사립(사인)  2018-03-01
# 3    강남유치원       피영민  박춘옥  1985-02-01  사립(사인)  1985-02-01
# 4    강남유치원       정지건  이성미  1971-03-30  사립(사인)  1971-03-30
#
#                  담당행정기관          전화번호                     홈페이지  \
# 0  서울특별시교육청 / 강동송파교육지원청   02-427-3151          등록된 홈페이지가 없습니다.
# 1    서울특별시교육청 / 중부교육지원청   02-362-7593          등록된 홈페이지가 없습니다.
# 2  서울특별시교육청 / 강남서초교육지원청  02-2226-9500  http://www.gnyujung.com
# 3  서울특별시교육청 / 강남서초교육지원청   02-546-1673          등록된 홈페이지가 없습니다.
# 4  서울특별시교육청 / 동작관악교육지원청   02-813-7122          등록된 홈페이지가 없습니다.
#
#                 운영시간  ...  1년이상2년미만 2년이상4년미만 4년이상6년미만 6년이상   평가(인증)년월  \
# 0  09 : 00 ~ 19 : 00  ...         5        0        0    0  2014년 10월
# 1  09 : 00 ~ 14 : 00  ...         0        1        0    0  2016년 09월
# ...

# %%
del.kinder_info2['총 교사수']
# Out:
#   File "<ipython-input-137-c290efb6563f>", line 1
#     del.kinder_info2['총 교사수']
#        ^
# SyntaxError: invalid syntax

# %%
del kinder_info2['총 교사수']

# %%
kinder_info2.head()
# Out:
#       유치원명       대표자   원장        설립일자    설립유형        개원일자  \
# 0    가람유치원       박민정  이형미  1986-11-27  사립(사인)  1987-03-10
# 1    가명유치원       염수정  노현경  1956-04-15  사립(법인)  1956-04-15
# 2  강남유정유치원  김지은, 박민정  박민정  2018-01-31  사립(사인)  2018-03-01
# 3    강남유치원       피영민  박춘옥  1985-02-01  사립(사인)  1985-02-01
# 4    강남유치원       정지건  이성미  1971-03-30  사립(사인)  1971-03-30
#
#                  담당행정기관          전화번호                     홈페이지  \
# 0  서울특별시교육청 / 강동송파교육지원청   02-427-3151          등록된 홈페이지가 없습니다.
# 1    서울특별시교육청 / 중부교육지원청   02-362-7593          등록된 홈페이지가 없습니다.
# 2  서울특별시교육청 / 강남서초교육지원청  02-2226-9500  http://www.gnyujung.com
# 3  서울특별시교육청 / 강남서초교육지원청   02-546-1673          등록된 홈페이지가 없습니다.
# 4  서울특별시교육청 / 동작관악교육지원청   02-813-7122          등록된 홈페이지가 없습니다.
#
#                 운영시간  ...  1년미만 1년이상2년미만 2년이상4년미만 4년이상6년미만 6년이상   평가(인증)년월  \
# 0  09 : 00 ~ 19 : 00  ...     3        5        0        0    0  2014년 10월
# 1  09 : 00 ~ 14 : 00  ...     2        0        1        0    0  2016년 09월
# ...

# %%
kinder_info2['3세반학생수'] = [float(value) for value in kinder_info2['3세반학생수']]
kinder_info2['4세반학생수'] = [float(value) for value in kinder_info2['4세반학생수']]
kinder_info2['5세반학생수'] = [float(value) for value in kinder_info2['5세반학생수']]
kinder_info2['3~4세반학생수'] = [float(value) for value in kinder_info2['3~4세반학생수']]
kinder_info2['4~5세반학생수'] = [float(value) for value in kinder_info2['4~5세반학생수']]
kinder_info2['3~5세반학생수'] = [float(value) for value in kinder_info2['3~5세반학생수']]
kinder_info2['특수/장애반학생수'] = [float(value) for value in kinder_info2['특수/장애반학생수']]
# Out:
# /Users/wonbang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/wonbang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/wonbang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %%
kinder_info2['총등록학생수'] = kinder_info2['3세반학생수'] + kinder_info2['4세반학생수'] + kinder_info2['5세반학생수'] + kinder_info2['3~4세반학생수'] + kinder_info2['4~5세반학생수'] + kinder_info2['3~5세반학생수'] + kinder_info2['특수/장애반학생수']
# Out:
# /Users/wonbang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
kinder_info2['총등록학생수']
# Out:
# 0      157.0
# 1       78.0
# 2      211.0
# 3      126.0
# 4       64.0
# 5      400.0
# 6       60.0
# 7      150.0
# 8      224.0
# 9      132.0
# 10      68.0
# 11     363.0
# 12      84.0
# 13     184.0
# 14     139.0
# 15     177.0
# 16      86.0
# 17      58.0
# 18      25.0
# 19     147.0
# 20     151.0
# 21     238.0
# 22      87.0
# 23     119.0
# 24     186.0
# 25      41.0
# 26      80.0
# 27     179.0
# 28     102.0
# 29      54.0
#        ...
# 932    179.0
# 933    137.0
# 934     57.0
# 935    138.0
# 936    117.0
# 937     52.0
# 938    145.0
# 939     30.0
# 940     61.0
# 941    120.0
# 942    120.0
# 943    117.0
# 944    134.0
# 945      0.0
# 946      0.0
# 947     18.0
# 948    187.0
# 949    131.0
# 950    160.0
# 951     48.0
# 952     59.0
# 953     79.0
# 954     53.0
# 955     15.0
# 956     63.0
# 957     22.0
# 958    182.0
# 959     82.0
# 960    114.0
# 961     47.0
# Name: 총등록학생수, Length: 929, dtype: float64

# %%
kinder_info2['비율'] = kinder_info2['총등록학생수'] / kinder_info2['총교사수']
kinder_info2['비율']
# Out:
# /Users/wonbang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 0      11.214286
# 1      13.000000
# 2       6.806452
# 3       9.000000
# 4       6.400000
# 5       9.756098
# 6       6.666667
# 7       7.500000
# 8       5.743590
# 9       7.764706
# 10      7.555556
# 11     11.709677
# 12     12.000000
# 13      7.666667
# 14      6.318182
# 15      8.428571
# 16      7.818182
# 17      5.800000
# 18      3.125000
# 19     16.333333
# 20      8.882353
# 21      8.500000
# 22      8.700000
# 23      6.611111
# 24      6.413793
# 25      5.125000
# 26      7.272727
# 27      8.523810
# 28      6.800000
# 29     10.800000
#          ...
# ...

# %%
import folium
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)

for n in kinder_info2.index:
    folium.Marker([kinder_info2['lat'][n],
                   kinder_info2['lng'][n]]).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
