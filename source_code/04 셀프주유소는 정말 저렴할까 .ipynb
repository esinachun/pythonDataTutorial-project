# %%
from selenium import webdriver
driver = webdriver.Chrome('../driver/chromedriver')
driver.get("http://www.opinet.co.kr/searRgSelect.do")

# %%
gu_list_raw = driver.find_element_by_xpath("""//*[@id="SIGUNGU_NM0"]""")
gu_list = gu_list_raw.find_elements_by_tag_name("option")

# %%
gu_list #opinet에 option의 value값으로 구 이름을 적어 두었다
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-10")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-11")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-12")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-13")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-14")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-15")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-16")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-17")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-18")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-19")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-20")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-21")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-22")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-23")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-24")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-26")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2a40a5a20502454c6bf0c8b6b1691412", element="0.6162176699564781-27")>]

# %%
gu_names = [option.get_attribute("value") for option in gu_list]
gu_names.remove('')
gu_names
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
element = driver.find_element_by_id("SIGUNGU_NM0")
element.send_keys(gu_names[0])

# %%
xpath = """//*[@id="searRgSelect"]"""
element_sel_gu = driver.find_element_by_xpath(xpath).click()

# %%
xpath = """//*[@id="glopopd_excel"]"""
element_get_excel = driver.find_element_by_xpath(xpath).click()

# %%
import time
from tqdm import tqdm_notebook

for gu in tqdm_notebook(gu_names):
    element = driver.find_element_by_id("SIGUNGU_NM0")
    element.send_keys(gu)
    
    time.sleep(2)
    
    xpath = """//*[@id="searRgSelect"]"""
    element_sel_gu = driver.find_element_by_xpath(xpath).click()
    
    time.sleep(1)
    
    xpath = """//*[@id="glopopd_excel"]"""
    element_get_excel = driver.find_element_by_xpath(xpath).click()
    
    time.sleep(1)
# Out:
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))

# %%
len(gu_names)
# Out:
# 25

# %%
driver.close()

# %%
import pandas as pd
from glob import glob

# %%
glob('../data/*).xls') #한글 검색이 잘 안됨..
# Out:
# ['../data/지역_위치별(주유소) (9).xls',
#  '../data/지역_위치별(주유소) (12).xls',
#  '../data/지역_위치별(주유소) (5).xls',
#  '../data/지역_위치별(주유소) (24).xls',
#  '../data/지역_위치별(주유소) (4).xls',
#  '../data/지역_위치별(주유소) (13).xls',
#  '../data/지역_위치별(주유소) (8).xls',
#  '../data/지역_위치별(주유소) (3).xls',
#  '../data/지역_위치별(주유소) (18).xls',
#  '../data/지역_위치별(주유소) (22).xls',
#  '../data/지역_위치별(주유소) (14).xls',
#  '../data/지역_위치별(주유소) (15).xls',
#  '../data/지역_위치별(주유소) (23).xls',
#  '../data/지역_위치별(주유소) (19).xls',
#  '../data/지역_위치별(주유소) (2).xls',
#  '../data/지역_위치별(주유소) (20).xls',
#  '../data/지역_위치별(주유소) (1).xls',
#  '../data/지역_위치별(주유소) (16).xls',
#  '../data/지역_위치별(주유소) (17).xls',
#  '../data/지역_위치별(주유소) (21).xls',
#  '../data/지역_위치별(주유소) (10).xls',
#  '../data/지역_위치별(주유소).xls',
#  '../data/지역_위치별(주유소) (7).xls',
#  '../data/지역_위치별(주유소) (6).xls',
#  '../data/지역_위치별(주유소) (11).xls']

# %%
stations_files = glob('../data/*).xls')
stations_files
# Out:
# ['../data/지역_위치별(주유소) (9).xls',
#  '../data/지역_위치별(주유소) (12).xls',
#  '../data/지역_위치별(주유소) (5).xls',
#  '../data/지역_위치별(주유소) (24).xls',
#  '../data/지역_위치별(주유소) (4).xls',
#  '../data/지역_위치별(주유소) (13).xls',
#  '../data/지역_위치별(주유소) (8).xls',
#  '../data/지역_위치별(주유소) (3).xls',
#  '../data/지역_위치별(주유소) (18).xls',
#  '../data/지역_위치별(주유소) (22).xls',
#  '../data/지역_위치별(주유소) (14).xls',
#  '../data/지역_위치별(주유소) (15).xls',
#  '../data/지역_위치별(주유소) (23).xls',
#  '../data/지역_위치별(주유소) (19).xls',
#  '../data/지역_위치별(주유소) (2).xls',
#  '../data/지역_위치별(주유소) (20).xls',
#  '../data/지역_위치별(주유소) (1).xls',
#  '../data/지역_위치별(주유소) (16).xls',
#  '../data/지역_위치별(주유소) (17).xls',
#  '../data/지역_위치별(주유소) (21).xls',
#  '../data/지역_위치별(주유소) (10).xls',
#  '../data/지역_위치별(주유소).xls',
#  '../data/지역_위치별(주유소) (7).xls',
#  '../data/지역_위치별(주유소) (6).xls',
#  '../data/지역_위치별(주유소) (11).xls']

# %%
len(stations_files)
# Out:
# 25

# %%
#파일을 하나로 합침
tmp_raw = []

for file_name in stations_files:
    tmp = pd.read_excel(file_name, header=2)
    tmp_raw.append(tmp)
    
station_raw = pd.concat(tmp_raw)

# %%
station_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 522 entries, 0 to 10
# Data columns (total 10 columns):
# 지역       522 non-null object
# 상호       522 non-null object
# 주소       522 non-null object
# 상표       522 non-null object
# 전화번호     522 non-null object
# 셀프여부     522 non-null object
# 고급휘발유    522 non-null object
# 휘발유      522 non-null object
# 경유       522 non-null object
# 실내등유     522 non-null object
# dtypes: object(10)
# memory usage: 44.9+ KB

# %%
station_raw.head()
# Out:
#       지역                상호                        주소      상표         전화번호  \
# 0  서울특별시   도봉제일주유소(주)송만에너지  서울특별시 도봉구  도봉로 783 (도봉동)  현대오일뱅크  02-955-5185
# 1  서울특별시  한이에너지(주)KLP제1주유소   서울특별시 도봉구  도봉로 596 (창동)  현대오일뱅크  02-902-5189
# 2  서울특별시      극동유화(주)대안주유소       서울 도봉구 마들로 574 (창동)   S-OIL  02-996-6640
# 3  서울특별시          정다운셀프주유소   서울특별시 도봉구 도봉로 635 (쌍문동)   SK에너지  02-996-5151
# 4  서울특별시             쌍문주유소  서울특별시 도봉구  도봉로 547 (쌍문동)   S-OIL  02-992-0220
#
#   셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    N     -  1570  1370   940
# 1    N     -  1571  1371     -
# 2    Y     -  1572  1372     -
# 3    Y     -  1577  1377     -
# 4    Y     -  1579  1379  1000

# %%
stations = pd.DataFrame({'Oil_store':station_raw['상호'],
                        '주소':station_raw['주소'],
                        '휘발유가격':station_raw['휘발유'],
                        '경유가격':station_raw['경유'],
                        '셀프':station_raw['셀프여부'],
                        '상표':station_raw['상표']  })
stations.head()
# Out:
#           Oil_store  경유가격      상표 셀프                        주소 휘발유가격
# 0   도봉제일주유소(주)송만에너지  1370  현대오일뱅크  N  서울특별시 도봉구  도봉로 783 (도봉동)  1570
# 1  한이에너지(주)KLP제1주유소  1371  현대오일뱅크  N   서울특별시 도봉구  도봉로 596 (창동)  1571
# 2      극동유화(주)대안주유소  1372   S-OIL  Y       서울 도봉구 마들로 574 (창동)  1572
# 3          정다운셀프주유소  1377   SK에너지  Y   서울특별시 도봉구 도봉로 635 (쌍문동)  1577
# 4             쌍문주유소  1379   S-OIL  Y  서울특별시 도봉구  도봉로 547 (쌍문동)  1579

# %%
stations['구'] = [eachAddress.split()[1] for eachAddress in stations['주소']]
stations.head()
# Out:
#           Oil_store  경유가격      상표 셀프                        주소 휘발유가격    구
# 0   도봉제일주유소(주)송만에너지  1370  현대오일뱅크  N  서울특별시 도봉구  도봉로 783 (도봉동)  1570  도봉구
# 1  한이에너지(주)KLP제1주유소  1371  현대오일뱅크  N   서울특별시 도봉구  도봉로 596 (창동)  1571  도봉구
# 2      극동유화(주)대안주유소  1372   S-OIL  Y       서울 도봉구 마들로 574 (창동)  1572  도봉구
# 3          정다운셀프주유소  1377   SK에너지  Y   서울특별시 도봉구 도봉로 635 (쌍문동)  1577  도봉구
# 4             쌍문주유소  1379   S-OIL  Y  서울특별시 도봉구  도봉로 547 (쌍문동)  1579  도봉구

# %%
#구 이름 체크
stations['구'].unique()
# Out:
# array(['도봉구', '특별시', '마포구', '광진구', '중랑구', '관악구', '서대문구', '노원구', '강서구',
#        '양천구', '종로구', '서초구', '성동구', '서울특별시', '중구', '영등포구', '강북구', '용산구',
#        '강동구', '성북구', '송파구', '은평구', '동대문구', '강남구', '금천구', '구로구', '동작구'],
#       dtype=object)

# %%
stations[stations['구']=='서울특별시']
# Out:
#          Oil_store  경유가격     상표 셀프                           주소 휘발유가격      구
# 11  SK네트웍스(주)효진주유소  1529  SK에너지  N  1 서울특별시 성동구 동일로 129 (성수동2가)  1729  서울특별시

# %%
stations.loc[stations['구']=='서울특별시', '구'] = '성동구'
stations['구'].unique()
# Out:
# array(['도봉구', '특별시', '마포구', '광진구', '중랑구', '관악구', '서대문구', '노원구', '강서구',
#        '양천구', '종로구', '서초구', '성동구', '중구', '영등포구', '강북구', '용산구', '강동구',
#        '성북구', '송파구', '은평구', '동대문구', '강남구', '금천구', '구로구', '동작구'],
#       dtype=object)

# %%
stations[stations['구']=='특별시']
# Out:
#    Oil_store  경유가격     상표 셀프                        주소 휘발유가격    구
# 13     서현주유소  1419  S-OIL  Y  서울 특별시 도봉구 방학로 142 (방학동)  1628  특별시

# %%
stations.loc[stations['구']=='특별시', '구'] = '도봉구'
stations['구'].unique()
# Out:
# array(['도봉구', '마포구', '광진구', '중랑구', '관악구', '서대문구', '노원구', '강서구', '양천구',
#        '종로구', '서초구', '성동구', '중구', '영등포구', '강북구', '용산구', '강동구', '성북구',
#        '송파구', '은평구', '동대문구', '강남구', '금천구', '구로구', '동작구'], dtype=object)

# %%
stations[stations['휘발유가격']=='-']
# Out:
#         Oil_store 경유가격     상표 셀프                          주소 휘발유가격     구
# 13          서강주유소    -  SK에너지  N        서울 마포구 독막로 134 (창전동)     -   마포구
# 17          형제주유소    -  S-OIL  N     서울 관악구 남부순환로 1520 (신림동)     -   관악구
# 34        하이웨이주유소    -  S-OIL  N       서울 강서구 공항대로 432 (화곡동)     -   강서구
# 25          목동주유소    -  S-OIL  N       서울 양천구 목동중앙로 125 (목동)     -   양천구
# 8          자하문주유소    -  SK에너지  N       서울 종로구 자하문로 248 (부암동)     -   종로구
# 34          하나주유소    -  S-OIL  N   서울특별시 영등포구  도림로 236 (신길동)     -  영등포구
# 18  명진석유(주)동서울주유소    -  GS칼텍스  Y  서울특별시 강동구  천호대로 1456 (상일동)     -   강동구
# 42          역삼주유소    -  GS칼텍스  N    서울특별시 강남구  논현로 426 (역삼동)     -   강남구

# %%
stations[stations['경유가격']=='-']
# Out:
#         Oil_store 경유가격     상표 셀프                          주소 휘발유가격     구
# 13          서강주유소    -  SK에너지  N        서울 마포구 독막로 134 (창전동)     -   마포구
# 17          형제주유소    -  S-OIL  N     서울 관악구 남부순환로 1520 (신림동)     -   관악구
# 34        하이웨이주유소    -  S-OIL  N       서울 강서구 공항대로 432 (화곡동)     -   강서구
# 25          목동주유소    -  S-OIL  N       서울 양천구 목동중앙로 125 (목동)     -   양천구
# 8          자하문주유소    -  SK에너지  N       서울 종로구 자하문로 248 (부암동)     -   종로구
# 34          하나주유소    -  S-OIL  N   서울특별시 영등포구  도림로 236 (신길동)     -  영등포구
# 18  명진석유(주)동서울주유소    -  GS칼텍스  Y  서울특별시 강동구  천호대로 1456 (상일동)     -   강동구
# 42          역삼주유소    -  GS칼텍스  N    서울특별시 강남구  논현로 426 (역삼동)     -   강남구

# %%
#가격없는 경우 예외 처리
stations = stations[stations['휘발유가격'] != '-']
stations.head()
# Out:
#           Oil_store  경유가격      상표 셀프                        주소 휘발유가격    구
# 0   도봉제일주유소(주)송만에너지  1370  현대오일뱅크  N  서울특별시 도봉구  도봉로 783 (도봉동)  1570  도봉구
# 1  한이에너지(주)KLP제1주유소  1371  현대오일뱅크  N   서울특별시 도봉구  도봉로 596 (창동)  1571  도봉구
# 2      극동유화(주)대안주유소  1372   S-OIL  Y       서울 도봉구 마들로 574 (창동)  1572  도봉구
# 3          정다운셀프주유소  1377   SK에너지  Y   서울특별시 도봉구 도봉로 635 (쌍문동)  1577  도봉구
# 4             쌍문주유소  1379   S-OIL  Y  서울특별시 도봉구  도봉로 547 (쌍문동)  1579  도봉구

# %%
#가격정보를 숫자형으로 변경 - 에러는 뜨는데 되긴 함...
stations['휘발유가격'] = [float(value) for value in stations['휘발유가격']]
stations['경유가격'] = [float(value) for value in stations['경유가격']]
# Out:
# /Users/wonbang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/wonbang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#index 중복 reset
stations.reset_index(inplace=True)
del stations['index']

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 514 entries, 0 to 513
# Data columns (total 7 columns):
# Oil_store    514 non-null object
# 경유가격         514 non-null float64
# 상표           514 non-null object
# 셀프           514 non-null object
# 주소           514 non-null object
# 휘발유가격        514 non-null float64
# 구            514 non-null object
# dtypes: float64(2), object(5)
# memory usage: 28.2+ KB

# %%
#boxplot그리기
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#한글문제 해결
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
     path = "c:/Windows/Fonts/malgun.ttf"
     font_name = font_manager.FontProperties(fname=path).get_name()
     rc('font', family=font_name)
else:
     print('Unknown system... sorry~~~~')

# %%
stations.boxplot(column='휘발유가격', by='셀프', figsize=(12,8));

# %%
#경유 가격 동향 비교
stations.boxplot(column='경유가격', by='셀프', figsize=(12,8));

# %%
#주유소 상표별로 가격 동향
plt.figure(figsize=(12,8))
sns.boxplot(x='상표', y='휘발유가격', hue='셀프', data=stations, palette='Set3')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="상표", y="휘발유가격", data=stations, palette="Set3")
sns.swarmplot(x="상표", y="휘발유가격", data=stations, color=".6")
plt.show()

# %%
#서울시 구별 주유 가격 확인하기
import json
import folium
import googlemaps
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
stations.sort_values(by="휘발유가격", ascending=False).head(10)
# Out:
#           Oil_store    경유가격     상표 셀프                        주소   휘발유가격    구
# 252           서남주유소  2097.0  SK에너지  N      서울 중구 통일로 30 (봉래동1가)  2282.0   중구
# 251           장충주유소  2058.0  SK에너지  N    서울 중구 장충단로 202 (장충동1가)  2281.0   중구
# 222           양재주유소  2057.0  SK에너지  N     서울 서초구 바우뫼로 178 (양재동)  2279.0  서초구
# 466         뉴서울(강남)  1998.0  SK에너지  N      서울 강남구 언주로 716 (논현동)  2210.0  강남구
# 250           필동주유소  1967.0  GS칼텍스  N  서울특별시 중구  퇴계로 196 (필동2가)  2169.0   중구
# 311            한남지점  1968.0  SK에너지  N    서울 용산구 한남대로21길 4 (한남동)  2168.0  용산구
# 181        (주)대양씨앤씨  1966.0  GS칼텍스  N       서울 종로구 사직로 65 (사직동)  2168.0  종로구
# 180  (주)중앙에너비스혜화주유소  1968.0  SK에너지  N    서울 종로구 창경궁로35길 1 (혜화동)  2168.0  종로구
# 249  주)중앙에너비스 퇴계로지점  1968.0  SK에너지  N  서울특별시 중구  퇴계로 228 (필동2가)  2168.0   중구
# 312            에너비스  1968.0  SK에너지  N    서울 용산구 한남대로21길 4 (한남동)  2168.0  용산구

# %%
stations.sort_values(by="휘발유가격", ascending=True).head(10)
# Out:
#              Oil_store    경유가격      상표 셀프                        주소   휘발유가격  \
# 287           북서울고속주유소  1337.0   S-OIL  Y   서울특별시 강북구 삼양로 410 (수유동)  1537.0
# 385             타이거주유소  1364.0   SK에너지  Y      서울 은평구 수색로 188 (증산동)  1554.0
# 386  (주)명연에너지 수색훼미리주유소  1363.0  현대오일뱅크  Y      서울 은평구 수색로 236 (수색동)  1557.0
# 481             풀페이주유소  1359.0   SK에너지  N    서울특별시 구로구 경인로 41 (온수동)  1558.0
# 288  (주)에프알엔디 직영 송정주유소  1363.0   SK에너지  N  서울특별시 강북구 인수봉로 185 (수유동)  1563.0
# 32               평안주유소  1376.0   알뜰주유소  N      서울 광진구 천호대로 630 (능동)  1566.0
# 31   현대오일뱅크(주)직영 능동주유소  1376.0  현대오일뱅크  Y  서울특별시 광진구  천호대로 584 (능동)  1566.0
# 387              수색뉴타운  1357.0   GS칼텍스  Y  서울특별시 은평구  수색로 350 (수색동)  1567.0
# 48             신일셀프주유소  1368.0   SK에너지  Y       서울 중랑구 상봉로 58 (망우동)  1568.0
# 223        (주)서울에너지 직영  1378.0   S-OIL  Y     서울 성동구 천호대로 324 (용답동)  1568.0
#
#        구
# 287  강북구
# 385  은평구
# 386  은평구
# 481  구로구
# 288  강북구
# 32   광진구
# 31   광진구
# 387  은평구
# 48   중랑구
# 223  성동구

# %%
#구별 평균 가격 구하기
import numpy as np
gu_data = pd.pivot_table(stations, index=["구"], values=["휘발유가격"], aggfunc=np.mean)
gu_data.head()
# Out:
#            휘발유가격
# 구
# 강남구  1847.071429
# 강동구  1695.388889
# 강북구  1584.727273
# 강서구  1641.764706
# 관악구  1650.411765

# %%
geo_path = '../data/02. skorea_municipalities_geo_simple.json'
geo_data = json.load(open(geo_path, encoding='utf-8'))

map = folium.Map(location=[37.5502, 126.982], zoom_start=10.5, tiles='Stamen Toner')
map.choropleth(geo_data = geo_path, 
               data = gu_data, 
               columns=[gu_data.index, '휘발유가격'], 
               fill_color='PuRd', #PuRd, Y1GnBu
               key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#서울시 주유 가격 상위 10개 주유소 지도에 표기하기
oil_price_top10 = stations.sort_values(by='휘발유가격', ascending=False).head(10)
oil_price_top10
# Out:
#           Oil_store    경유가격     상표 셀프                        주소   휘발유가격    구
# 252           서남주유소  2097.0  SK에너지  N      서울 중구 통일로 30 (봉래동1가)  2282.0   중구
# 251           장충주유소  2058.0  SK에너지  N    서울 중구 장충단로 202 (장충동1가)  2281.0   중구
# 222           양재주유소  2057.0  SK에너지  N     서울 서초구 바우뫼로 178 (양재동)  2279.0  서초구
# 466         뉴서울(강남)  1998.0  SK에너지  N      서울 강남구 언주로 716 (논현동)  2210.0  강남구
# 250           필동주유소  1967.0  GS칼텍스  N  서울특별시 중구  퇴계로 196 (필동2가)  2169.0   중구
# 311            한남지점  1968.0  SK에너지  N    서울 용산구 한남대로21길 4 (한남동)  2168.0  용산구
# 181        (주)대양씨앤씨  1966.0  GS칼텍스  N       서울 종로구 사직로 65 (사직동)  2168.0  종로구
# 180  (주)중앙에너비스혜화주유소  1968.0  SK에너지  N    서울 종로구 창경궁로35길 1 (혜화동)  2168.0  종로구
# 249  주)중앙에너비스 퇴계로지점  1968.0  SK에너지  N  서울특별시 중구  퇴계로 228 (필동2가)  2168.0   중구
# 312            에너비스  1968.0  SK에너지  N    서울 용산구 한남대로21길 4 (한남동)  2168.0  용산구

# %%
#서울시 주유 가격 하위 10개 주유소 지도에 표기하기
oil_price_bottom10 = stations.sort_values(by='휘발유가격', ascending=True).head(10)
oil_price_bottom10
# Out:
#              Oil_store    경유가격      상표 셀프                        주소   휘발유가격  \
# 287           북서울고속주유소  1337.0   S-OIL  Y   서울특별시 강북구 삼양로 410 (수유동)  1537.0
# 385             타이거주유소  1364.0   SK에너지  Y      서울 은평구 수색로 188 (증산동)  1554.0
# 386  (주)명연에너지 수색훼미리주유소  1363.0  현대오일뱅크  Y      서울 은평구 수색로 236 (수색동)  1557.0
# 481             풀페이주유소  1359.0   SK에너지  N    서울특별시 구로구 경인로 41 (온수동)  1558.0
# 288  (주)에프알엔디 직영 송정주유소  1363.0   SK에너지  N  서울특별시 강북구 인수봉로 185 (수유동)  1563.0
# 32               평안주유소  1376.0   알뜰주유소  N      서울 광진구 천호대로 630 (능동)  1566.0
# 31   현대오일뱅크(주)직영 능동주유소  1376.0  현대오일뱅크  Y  서울특별시 광진구  천호대로 584 (능동)  1566.0
# 387              수색뉴타운  1357.0   GS칼텍스  Y  서울특별시 은평구  수색로 350 (수색동)  1567.0
# 48             신일셀프주유소  1368.0   SK에너지  Y       서울 중랑구 상봉로 58 (망우동)  1568.0
# 223        (주)서울에너지 직영  1378.0   S-OIL  Y     서울 성동구 천호대로 324 (용답동)  1568.0
#
#        구
# 287  강북구
# 385  은평구
# 386  은평구
# 481  구로구
# 288  강북구
# 32   광진구
# 31   광진구
# 387  은평구
# 48   중랑구
# 223  성동구

# %%
gmaps_key = "AIzaSyCVc3Mc-v8efQxIykNPK8nqFXK9DaE7KA4"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
from tqdm import tqdm_notebook

lat = []
lng = []

for n in tqdm_notebook(oil_price_top10.index):
    try:
        tmp_add = str(oil_price_top10['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)
        
        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
        
        
oil_price_top10['lat'] = lat
oil_price_top10['lng'] = lng
oil_price_top10
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
#           Oil_store    경유가격     상표 셀프                        주소   휘발유가격    구  \
# 252           서남주유소  2097.0  SK에너지  N      서울 중구 통일로 30 (봉래동1가)  2282.0   중구
# 251           장충주유소  2058.0  SK에너지  N    서울 중구 장충단로 202 (장충동1가)  2281.0   중구
# 222           양재주유소  2057.0  SK에너지  N     서울 서초구 바우뫼로 178 (양재동)  2279.0  서초구
# 466         뉴서울(강남)  1998.0  SK에너지  N      서울 강남구 언주로 716 (논현동)  2210.0  강남구
# 250           필동주유소  1967.0  GS칼텍스  N  서울특별시 중구  퇴계로 196 (필동2가)  2169.0   중구
# 311            한남지점  1968.0  SK에너지  N    서울 용산구 한남대로21길 4 (한남동)  2168.0  용산구
# 181        (주)대양씨앤씨  1966.0  GS칼텍스  N       서울 종로구 사직로 65 (사직동)  2168.0  종로구
# 180  (주)중앙에너비스혜화주유소  1968.0  SK에너지  N    서울 종로구 창경궁로35길 1 (혜화동)  2168.0  종로구
# 249  주)중앙에너비스 퇴계로지점  1968.0  SK에너지  N  서울특별시 중구  퇴계로 228 (필동2가)  2168.0   중구
# 312            에너비스  1968.0  SK에너지  N    서울 용산구 한남대로21길 4 (한남동)  2168.0  용산구
#
#            lat         lng
# 252  37.558348  126.972090
# 251  37.562719  127.007010
# 222  37.478071  127.039610
# 466  37.517636  127.035756
# 250  37.560850  126.993653
# 311  37.534657  127.006063
# 181  37.574464  126.966618
# 180  37.586068  127.001058
# 249  37.561648  126.997142
# 312  37.534657  127.006063

# %%
from tqdm import tqdm_notebook

lat = []
lng = []

for n in tqdm_notebook(oil_price_bottom10.index):
    try:
        tmp_add = str(oil_price_bottom10['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)
        
        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
        
        
oil_price_bottom10['lat'] = lat
oil_price_bottom10['lng'] = lng
oil_price_bottom10
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
#              Oil_store    경유가격      상표 셀프                        주소   휘발유가격  \
# 287           북서울고속주유소  1337.0   S-OIL  Y   서울특별시 강북구 삼양로 410 (수유동)  1537.0
# 385             타이거주유소  1364.0   SK에너지  Y      서울 은평구 수색로 188 (증산동)  1554.0
# 386  (주)명연에너지 수색훼미리주유소  1363.0  현대오일뱅크  Y      서울 은평구 수색로 236 (수색동)  1557.0
# 481             풀페이주유소  1359.0   SK에너지  N    서울특별시 구로구 경인로 41 (온수동)  1558.0
# 288  (주)에프알엔디 직영 송정주유소  1363.0   SK에너지  N  서울특별시 강북구 인수봉로 185 (수유동)  1563.0
# 32               평안주유소  1376.0   알뜰주유소  N      서울 광진구 천호대로 630 (능동)  1566.0
# 31   현대오일뱅크(주)직영 능동주유소  1376.0  현대오일뱅크  Y  서울특별시 광진구  천호대로 584 (능동)  1566.0
# 387              수색뉴타운  1357.0   GS칼텍스  Y  서울특별시 은평구  수색로 350 (수색동)  1567.0
# 48             신일셀프주유소  1368.0   SK에너지  Y       서울 중랑구 상봉로 58 (망우동)  1568.0
# 223        (주)서울에너지 직영  1378.0   S-OIL  Y     서울 성동구 천호대로 324 (용답동)  1568.0
#
#        구        lat         lng
# 287  강북구  37.640155  127.017203
# 385  은평구  37.578424  126.902050
# 386  은평구  37.581122  126.897774
# 481  구로구  37.491009  126.826675
# 288  강북구  37.636166  127.012791
# 32   광진구  37.553737  127.087130
# 31   광진구  37.555573  127.082356
# 387  은평구  37.587107  126.887542
# 48   중랑구  37.590907  127.093834
# 223  성동구  37.564195  127.055579

# %%
#map 표시
map = folium.Map(location=[37.5202, 126.975], zoom_start=10.5)

for n in oil_price_top10.index:
    if pd.notnull(oil_price_top10['lat'][n]):
        folium.CircleMarker([oil_price_top10['lat'][n], oil_price_top10['lng'][n]],
                            radius=15, color='#CD3181',
                            fill='#CD3181'
                            ).add_to(map)
        
for n in oil_price_bottom10.index:
    if pd.notnull(oil_price_bottom10['lat'][n]):
        folium.CircleMarker([oil_price_bottom10['lat'][n], oil_price_bottom10['lng'][n]],
                            radius=15, color='#3186cc',
                            fill='#3186cc'
                            ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
